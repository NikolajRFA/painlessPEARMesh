# %%
from tools.chart_setup import chart_setup

energy_profile_id_map = {
    3211408993: 1,
    3211386233: 1,
    417643029: 1,
    3206780693: 1,
    2883627821: 1,
    3211302717: 1,
    2930999053: 1,
    2811362457: 1,
    3211321933: 1,
    3211320821: 1,
    3101225193: 1,
    1616231985: 1,
    3101224829: 1,
    3294674857: 1,
    2883624417: 1,
    2883613101: 1,
    3294675137: 1,
    2883639777: 1,
    3294679677: 1,
    3294675181: 1,
    2883681453: 1,
    2883619065: 1,
    3294677077: 1,
    2883632169: 1,
    3294679889: 1,
    2883641793: 1,
    3294680957: 1,
}

# %%
energy_profile_map = {
    1: (20, 15),
}

chart_setup("data/20-15 all", energy_profile_id_map, energy_profile_map, "20-15 all")
# Out:
# no pear 2 min avg: 625.4817351598173
# avg consumption post-PEAR: 656
# % difference between pre and post-PEAR avg consumption: -4.879161632495155
# Difference between max before and after PEAR 23.799999999999997
# 27.35632183908045
# pre-PEAR sum: 740.4, post-PEAR sum: 632.9999999999999

# %%
energy_profile_map = {
    1: (25, 20),
}

chart_setup("data/25-20 all", energy_profile_id_map, energy_profile_map, "25-20 all")
# Out:
# no pear 2 min avg: 625.4817351598173
# avg consumption post-PEAR: 567
# % difference between pre and post-PEAR avg consumption: 9.349870967035443
# Difference between max before and after PEAR 14.200000000000003
# 17.884130982367765
# pre-PEAR sum: 622.4000000000001, post-PEAR sum: 543.8000000000001

# %%
energy_profile_map = {
    1: (30, 25),
}

chart_setup("data/30-25 all", energy_profile_id_map, energy_profile_map, "30-25 all")
# Out:
# no pear 2 min avg: 625.4817351598173
# avg consumption post-PEAR: 610
# % difference between pre and post-PEAR avg consumption: 2.475169823442016
# Difference between max before and after PEAR 10.800000000000004
# 14.754098360655746
# pre-PEAR sum: 621.0000000000001, post-PEAR sum: 558.2
