# %%
from tools.chart_setup import chart_setup
energy_profile_map = {
    1: (60, 45),
    2: (20, 15),
}

# %%
energy_profile_id_map_H6L13 = {
    3211408993: 1,
    3211386233: 1,
    417643029: 1,
    3206780693: 1,
    2883627821: 1,
    3211302717: 1,
    2930999053: 2,
    2811362457: 2,
    3211321933: 2,
    3211320821: 2,
    3101225193: 2,
    1616231985: 2,
    3101224829: 2,
    3294674857: 2,
    2883624417: 2,
    2883613101: 2,
    3294675137: 2,
    2883639777: 2,
    3294679677: 2,
    3294675181: 2,
    2883681453: 2,
    2883619065: 2,
    3294677077: 2,
    2883632169: 2,
    3294679889: 2,
    2883641793: 2,
    3294680957: 2,
}

chart_setup("data/H6L13", energy_profile_id_map_H6L13, energy_profile_map, "H6L13")
# Out:
# Difference between max before and after PEAR 3.0
# 3.7783375314861445
# Difference between max before and after PEAR 21.200000000000003
# 35.215946843853814

# %%
energy_profile_id_map_H10L9 = {
    3211408993: 1,
    3211386233: 1,
    417643029: 1,
    3206780693: 1,
    2883627821: 1,
    3211302717: 1,
    2930999053: 1,
    2811362457: 1,
    3211321933: 2,#
    3211320821: 2,#
    3101225193: 1,
    1616231985: 2,#
    3101224829: 2,#
    3294674857: 1,
    2883624417: 2,#
    2883613101: 1,
    3294675137: 1,
    2883639777: 1,
    3294679677: 1,
    3294675181: 2,#
    2883681453: 1,
    2883619065: 2,#
    3294677077: 1,
    2883632169: 1,
    3294679889: 1,
    2883641793: 2,#
    3294680957: 2,#
}

chart_setup("data/H10L9", energy_profile_id_map_H10L9, energy_profile_map, "H10L9")
# Out:
# Difference between max before and after PEAR 0.7999999999999972
# 1.0695187165775337
# Difference between max before and after PEAR 29.400000000000006
# 47.26688102893891

# %%
energy_profile_id_map_H14L5 = {
    3211408993: 1,
    3211386233: 1,
    417643029: 1,
    3206780693: 1,
    2883627821: 1,
    3211302717: 1,
    2930999053: 1,
    2811362457: 1,
    3211321933: 1,
    3211320821: 1,
    3101225193: 1,
    1616231985: 1,
    3101224829: 2,#
    3294674857: 1,
    2883624417: 2,#
    2883613101: 1,
    3294675137: 1,
    2883639777: 1,
    3294679677: 1,
    3294675181: 1,
    2883681453: 1,
    2883619065: 2,#
    3294677077: 1,
    2883632169: 1,
    3294679889: 1,
    2883641793: 2,#
    3294680957: 2,#
}

chart_setup("data/H14L5", energy_profile_id_map_H14L5, energy_profile_map, "H14L5")
# Out:
# Difference between max before and after PEAR 10.0
# 13.44086021505376
# Difference between max before and after PEAR 27.4
# 53.72549019607843
