# %%
from tools.chart_setup import chart_setup

energy_profile_id_map = {
    3206773453: 0,
    3211408993: 1,
    3211386233: 1,
    417643029: 2,
    2930999053: 2,
    2811362457: 2,
    3211302717: 2,
    3206780693: 3,
    3211321933: 3,
    3211320821: 3,
    3101225193: 3,
    1616231985: 4,
    3101224829: 4,
    3294674857: 4,
    2883624417: 4,
    2883613101: 5,
    3294675137: 3,
    2883639777: 4,
    3294679677: 5,
    3294675181: 3,
    2883681453: 2,
    2883619065: 3,
    3294677077: 4,
    2883632169: 4,
    3294679889: 5,
    2883627821: 1,
    2883641793: 2,
    3294680957: 1
}

# %%
energy_profile_map = {
    0: (999, 999),
    1: (55, 50),
    2: (50, 45),
    3: (45, 40),
    4: (40, 35),
    5: (35, 30)
}

chart_setup("data/1st set", energy_profile_id_map, energy_profile_map, "1st set", True)
# Out:
# Difference between max before and after PEAR -4.599999999999994
# -7.301587301587304
# Difference between max before and after PEAR 3.4000000000000057
# 5.295950155763251
# Difference between max before and after PEAR 1.7999999999999972
# 3.5433070866141634
# Difference between max before and after PEAR -2.0
# -14.705882352941174

# %%
energy_profile_map = {
    0: (999, 999),
    1: (50, 45),
    2: (45, 40),
    3: (40, 35),
    4: (35, 30),
    5: (30, 25)
}

chart_setup("data/2nd set", energy_profile_id_map, energy_profile_map, "2nd set", True)
# Out:
# Difference between max before and after PEAR -2.0
# -3.257328990228018
# Difference between max before and after PEAR -3.200000000000003
# -4.444444444444457
# Difference between max before and after PEAR 10.399999999999999
# 19.69696969696969
# Difference between max before and after PEAR -0.8000000000000007
# -4.494382022471925

# %%
energy_profile_map = {
    0: (999, 999),
    1: (45, 40),
    2: (40, 35),
    3: (35, 30),
    4: (30, 25),
    5: (25, 20)
}

chart_setup("data/3rd set", energy_profile_id_map, energy_profile_map, "3rd set", True)
# Out:
# Difference between max before and after PEAR 3.799999999999997
# 5.234159779614316
# Difference between max before and after PEAR -8.0
# -15.209125475285163
# Difference between max before and after PEAR 16.0
# 29.090909090909093
# Difference between max before and after PEAR -2.3999999999999986
# -14.285714285714278

# %%
energy_profile_map = {
    0: (999, 999),
    1: (40, 35),
    2: (35, 30),
    3: (30, 25),
    4: (25, 20),
    5: (20, 15)
}

chart_setup("data/4th set", energy_profile_id_map, energy_profile_map, "4th set")
# Out:
# Difference between max before and after PEAR 12.799999999999997
# 17.391304347826093
# Difference between max before and after PEAR 15.399999999999991
# 20.92391304347825
# Difference between max before and after PEAR 0.0
# 0.0
# Difference between max before and after PEAR -4.399999999999999
# -23.655913978494624

# %%
energy_profile_map = {
    0: (999, 999),
    1: (35, 30),
    2: (30, 25),
    3: (25, 20),
    4: (20, 15),
    5: (15, 10)
}

chart_setup("data/5th set", energy_profile_id_map, energy_profile_map, "5th set")
# Out:
# Difference between max before and after PEAR 20.400000000000006
# 25.757575757575765
# Difference between max before and after PEAR 7.399999999999999
# 13.553113553113548
# Difference between max before and after PEAR 4.600000000000001
# 9.465020576131693
# Difference between max before and after PEAR -0.5999999999999979
# -2.5210084033613356

# %%
energy_profile_map = {
    0: (999, 999),
    1: (30, 25),
    2: (25, 20),
    3: (20, 15),
    4: (15, 10),
    5: (10, 5)
}

chart_setup("data/6th set", energy_profile_id_map, energy_profile_map, "6th set")
# Out:
# Difference between max before and after PEAR 42.60000000000001
# 47.65100671140941
# Difference between max before and after PEAR 20.200000000000003
# 31.366459627329192
# Difference between max before and after PEAR -6.0
# -15.384615384615373
# Difference between max before and after PEAR -2.5999999999999996
# -22.033898305084733

# %%
energy_profile_map = {
    0: (999, 999),
    1: (25, 20),
    2: (20, 15),
    3: (15, 10),
    4: (10, 5),
    5: (5, 0)
}

chart_setup("data/7th set", energy_profile_id_map, energy_profile_map, "7th set")
# Out:
# Difference between max before and after PEAR -0.5
# -0.735294117647058
# Difference between max before and after PEAR 9.0
# 15.450643776824037
# Difference between max before and after PEAR 22.5
# 41.28440366972477
# Difference between max before and after PEAR -3.5
# -13.861386138613852
