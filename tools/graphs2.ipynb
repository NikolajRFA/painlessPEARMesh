# %%
from tools.chart_setup import chart_setup

energy_profile_id_map_4_profile_tests = {
    3206773453: 0,
    3211408993: 1,
    3211386233: 1,
    417643029: 2,
    2930999053: 2,
    2811362457: 2,
    3211302717: 2,
    3206780693: 3,
    3211321933: 3,
    3211320821: 3,
    3101225193: 3,
    1616231985: 4,
    3101224829: 4,
    3294674857: 4,
    2883624417: 4,
    2883613101: 5,
    3294675137: 3,
    2883639777: 4,
    3294679677: 5,
    3294675181: 3,
    2883681453: 2,
    2883619065: 3,
    3294677077: 4,
    2883632169: 4,
    3294679889: 5,
    2883627821: 1,
    2883641793: 2,
    3294680957: 1
}

energy_profile_map_5th_set = {
    0: (999, 999),
    1: (35, 30),
    2: (30, 25),
    3: (25, 20),
    4: (20, 15),
    5: (15, 10)
}

chart_setup("data/5th set", energy_profile_id_map_4_profile_tests, energy_profile_map_5th_set, "5th Set")
# Out:
# Difference between max before and after PEAR 20.400000000000006
# 25.757575757575765
# Difference between max before and after PEAR 7.399999999999999
# 13.553113553113548
# Difference between max before and after PEAR 4.600000000000001
# 9.465020576131693
# Difference between max before and after PEAR -0.5999999999999979
# -2.5210084033613356
